# %% [markdown]
# # Chapter 5's solution

# %% [markdown]
# ## 5.1

# %% [markdown]
# $f'(x) = 4x^3\frac{1}{x^4}sin(x^3) + log(x^4)cos(x^3)3x^2 = \frac{4}{x}sin(x^3) + 3log(x^4)cos(x^3)x^2$

# %% [markdown]
# ## 5.2

# %% [markdown]
# $f(x) = (1 + exp(x))^{-1} = (1 + exp(-x))^{-2}e^{-x}$

# %% [markdown]
# ## 5.3

# %% [markdown]
# $f'(x) = 2exp(-\frac{1}{2\sigma^2}(x - μ)^2)(-\frac{1}{\sigma^2}(x-\mu))$

# %% [markdown]
# ## 5.4

# %% [markdown]
# $T_5 = 1 + x + \frac{-1}{2}x^2 + \frac{-1}{6}x^3 + \frac{1}{24}x^4 + \frac{1}{120}x^5$
#
# You can obtain the lower Taylor polynomial by pruning $T_5$.

# %% [markdown]
# ## 5.5

# %% [markdown]
# ### a.

# %% [markdown]
# $\frac{\partial f_1}{\partial x} \in ℝ^{1 \times 2}$
#
# $\frac{\partial f_2}{\partial x} \in ℝ^{1 \times n}$
#
# $\frac{\partial f_3}{\partial x} \in ℝ^{(n \times n) \times n}$

# %% [markdown]
# ### b.

# %% [markdown]
# $$\frac{\partial f_1}{∂x} = \begin{pmatrix}cos(x_1)cos(x_2)&-sin(x_1)sin(x_2)\end{pmatrix}$$
#
# $$\frac{\partial f_2}{\partial x} = y^T$$
#
#
# With the last function, which in $ℝ^{n \times n}$, the derivative will be a "row" tensor, with each element is the derivative of the matrix (the outer product matrix) with respect to each element of $x$: $x_i$. Set $y = xx^T$:
# $$\frac{\partial f_3}{\partial x} = \begin{pmatrix}\frac{∂y}{∂x_1}&...&\frac{\partial y}{\partial x_n}\end{pmatrix}
# $$
#
# We consider the outer product $xx^T$:
# $$y = \begin{pmatrix}x_1^2&x_1x_2&...&x_1x_n\\... & ... & ... & ...\\x_nx_1 & ... & ... & x_n^2\end{pmatrix}$$
#
# $\frac{∂y}{∂x_i}$ is taking the derivative of the outer product matrix with respect to $x_i$, elementwise.

# %% [markdown]
# ## 5.6

# %% [markdown]
# $f(t) = sin(log(t^Tt)), t \in ℝ^D$
#
# Set $z = t^Tt$, we have:
#
# $$\frac{d f}{dt} = \frac{df}{dz}\frac{dz}{dt} = cos(log(z))\frac{1}{z}\frac{dt^TIt}{dt} = cos(log(z))\frac{1}{z}t^T(I+I^T) = 2cos(log(z))\frac{1}{z}t^T$$

# %% [markdown]
# $g(X) = tr(AXB)$
#
# -skipped-

# %% [markdown]
# ## 5.7

# %% [markdown]
# ### a.

# %% [markdown]
# $$\frac{df}{dx} = \frac{df}{dz}\frac{dz}{dx} = \frac{2}{1+z}x^T$$

# %% [markdown]
# ### b.

# %% [markdown]
# $$\frac{df}{dx} = \frac{df}{dz}\frac{dz}{dx}$$
#
# We have $f(z) = \begin{pmatrix}sin(z_1)\\...\\sin(z_E)\end{pmatrix}$
#
# Thus, $\frac{df}{dz}$ will be a $E \times E$ matrix with the form:
#
# $$\begin{pmatrix}cos(z_1)&0&...&0\\0&cos(z_2)&...&0\\...&...&...&...\\0&0&0&cos(z_E)\end{pmatrix}$$
#
# $\frac{dz}{dx}$ is easier, using useful fomula in the book, we have the derivative is an $E \times D$ matrix, it is the matrix $A$ itself.

# %% [markdown]
# ## 5.8

# %% [markdown]
# ### a.

# %% [markdown]
# $$\frac{df}{dx} = \frac{df}{dz}\frac{dz}{dy}\frac{dy}{dx}$$
#
# Because $z$ is a scalar, $\frac{df}{dz} = \frac{-1}{2}e^{\frac{-1}{2}z}$
#
# With $\frac{dz}{dy}$, simple enough, using the useful formula in the book we have $\frac{dz}{dy} = y^T[S^{-1} + (S^{-1})^T]$, which is a row vector with the dimension $1 \times D$
#
# With $\frac{dy}{dx}$, it is the identity matrix, with the dimension $D \times D$

# %% [markdown]
# ### b.

# %% [markdown]
# $$f(x) = x_1^2 + ... + x_n^2 + n\sigma^2$$
#
# $$⇒\frac{df}{dx} = \frac{d(x_1^2 + ... +x_n^2)}{dx} = 2x^T$$

# %% [markdown]
# ### c.

# %% [markdown]
# This part is the same as 5.7b, just replace the non-zero of the diagonal matrix with the derivative of tanh function with the value of the corresponding element of $z$.

# %% [markdown]
# ## 5.9

# %% [markdown]
# $$\frac{dg}{dv} = \frac{dlogp}{dv} - \frac{dlogq}{dv} = \frac{dlogp}{dp}\frac{dp}{dz}\frac{dz}{dv} - \frac{dlogq}{dq}\frac{dq}{dv} = \frac{1}{p}p_z't_v' - \frac{1}{q}(\frac{dq}{dz}\frac{dz}{dv} + \frac{dq}{dv}) = \frac{1}{p}p_z't_v' - \frac{1}{q}(q'_zt'_v+q'_v)$$
