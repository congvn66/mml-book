# %% [markdown]
# # My solution for reciation 1

# %% [markdown]
# ## 1.

# %% [markdown]
# $P((A∩B^c)\cup(A^c\cap B)) = P(A\cap B^c) + P(A^c\cap B)$ (1) (using axiom 3)
#
# We have $P(A) = P((A \cap B)\cup (A \cap B^c)), P(B) = P((A \cap B)\cup (A^c \cap B))$. We can verify by breaking the parenthesis, or by using the axiom 3 for event $A$.
#
# Thus, the inital equation can be implied as follow:
# $(1) = P(A) - P(A\cap B) + P(B) - P(A\cap B) = P(A) + P(B) - 2P(A\cap B)$

# %% [markdown]
# ## 2.

# %% [markdown]
# $P(A^c \cap B^c) = 1 - P(A \cup B) = 1 - (P(A) + P(B) - P(A ∩ B)) = 0.1$

# %% [markdown]
# ## 3.

# %% [markdown]
# We have $\alpha$ is the probabiltity of an odd face of the dice. Therefore, we can find the value of $\alpha = \frac{1}{9}$, given the probability of an even face of the dice is $2\alpha$.
#
# $P(\{1, 2, 3\}) = P(\{1\}) + P(\{2\}) + P(\{3\}) = \frac{1}{9} + \frac{2}{9} + \frac{1}{9} = \frac{4}{9}$

# %% [markdown]
# ## 4.

# %% [markdown]
# Given all pairs of delays being equally likely, we can assign a probability for a given event in $[0, 1] \times [0, 1]$ is its area.
#
# We denote the delay time of Romeo and Juliet: $R$  and $J$. The problem can be phrased as finding the area of the following inequation in $[0, 1] \times [0, 1]$: $|R - J| \le \frac{1}{4}$ (1)
#
# The bounded region that has area that statisfied (1) is a polygon with those vertices: $(0, \frac{1}{4}), (\frac{1}{4}, 0), (0, 0), (1, \frac{3}{4}), (1, 1), (\frac{3}{4}, 1)$. Using basic geometry, we can find the polygon's area is $\frac{7}{16}$.
